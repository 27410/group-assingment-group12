# %%
 #memote report snapshot /mnt/c/Users/s164898/Documents/Cell_Factory/iNF517.xml.gz

# %%
pip install memote
# Out:
# ...
#
# ...
#      -------------------------------------- 964.1/964.1 kB 3.4 MB/s eta 0:00:00
# ...
#      ------------------------------------ 190.6/190.6 kB 823.4 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 58.0/58.0 kB 3.2 MB/s eta 0:00:00
# ...
#      ------------------------------------- 342.2/342.2 kB 10.7 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.2/1.2 MB 10.7 MB/s eta 0:00:00
# ...
#      -------------------------------------- 142.0/142.0 kB 8.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 75.0/75.0 kB 4.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 72.1/72.1 kB 4.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 85.8/85.8 kB ? eta 0:00:00
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 68.9/68.9 kB 3.9 MB/s eta 0:00:00
# ...

# %%
# !memote report snapshot iNF517.xml
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.9.13, pytest-4.6.11, py-1.11.0, pluggy-0.13.1
# rootdir: C:\Users\s164898
# plugins: anyio-3.5.0
# collected 155 items / 1 skipped / 154 selected
#
# ..\..\..\Anaconda3\Lib\site-packages\memote\suite\tests\test_annotation.py . [  0%]
# ..FFFFFFFFF.FFFFF.FFFFFFFFFFFFFFF..FF..F...F....FFF.FFFFFFFFFF..         [ 41%]
# ..\..\..\Anaconda3\Lib\site-packages\memote\suite\tests\test_basic.py .. [ 43%]
# ....F........F...F.FF                                                    [ 56%]
# ..\..\..\Anaconda3\Lib\site-packages\memote\suite\tests\test_biomass.py . [ 57%]
# FF.F.F.....FFF..FF                                                       [ 69%]
# ..\..\..\Anaconda3\Lib\site-packages\memote\suite\tests\test_consistency.py . [ 69%]
# ..ssssssssssssssssFFFFFF.FF.                                             [ 87%]
# ...
